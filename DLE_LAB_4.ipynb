# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
max_features = 10000

(x_train, y_train), (x_test, y_test) = keras.datasets.imdb.load_data(num_words=max_features)

print("Train shape:", len(x_train))
print("Test shape:", len(x_test))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Train shape: 25000
# Test shape: 25000

# %%
maxlen = 200

x_train = keras.preprocessing.sequence.pad_sequences(x_train, maxlen=maxlen)
x_test = keras.preprocessing.sequence.pad_sequences(x_test, maxlen=maxlen)

print(x_train.shape)
# Out:
# (25000, 200)

# %%
model = keras.Sequential([
    layers.Embedding(input_dim=max_features, output_dim=128, input_length=maxlen),
    layers.LSTM(64, return_sequences=False),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

history = model.fit(
    x_train, y_train,
    batch_size=32,
    epochs=5,
    validation_split=0.2
)
# Out:
# Epoch 1/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 120ms/step - accuracy: 0.8012 - loss: 0.4260 - val_accuracy: 0.8540 - val_loss: 0.3509
# Epoch 2/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 119ms/step - accuracy: 0.9032 - loss: 0.2496 - val_accuracy: 0.8660 - val_loss: 0.3490
# Epoch 3/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.9319 - loss: 0.1823 - val_accuracy: 0.8676 - val_loss: 0.3855
# Epoch 4/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 74s 117ms/step - accuracy: 0.9513 - loss: 0.1325 - val_accuracy: 0.8588 - val_loss: 0.4001
# Epoch 5/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 83s 119ms/step - accuracy: 0.9716 - loss: 0.0831 - val_accuracy: 0.8546 - val_loss: 0.5123

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test Loss:", test_loss)
print("Test Accuracy:", test_acc)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 24s 31ms/step - accuracy: 0.8554 - loss: 0.5059
# Test Loss: 0.5058634877204895
# Test Accuracy: 0.855400025844574
